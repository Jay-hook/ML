# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# 가상의 데이터 생성
X= data = np.linspace(1,2,200) # 시작값=1, 종료값=2, 개수=200
y= X*4 + np.random.randn(200) * 0.3 # X를 4배로 하고 편차 0.3 정도의 가우시안 잡음 추가

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(1, input_dim=1, activation='linear'))
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
model.fit(X, y, batch_size=1, epochs=30)
# Out:
# Epoch 1/30
# 200/200 [==============================] - 2s 5ms/step - loss: 2.2047 - mse: 2.2047
# Epoch 2/30
# 200/200 [==============================] - 1s 5ms/step - loss: 0.2253 - mse: 0.2253
# Epoch 3/30
# 200/200 [==============================] - 1s 7ms/step - loss: 0.2022 - mse: 0.2022
# Epoch 4/30
# 200/200 [==============================] - 2s 8ms/step - loss: 0.1811 - mse: 0.1811
# Epoch 5/30
# 200/200 [==============================] - 2s 8ms/step - loss: 0.1642 - mse: 0.1642
# Epoch 6/30
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1511 - mse: 0.1511
# Epoch 7/30
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1427 - mse: 0.1427
# Epoch 8/30
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1346 - mse: 0.1346
# Epoch 9/30
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1285 - mse: 0.1285
# Epoch 10/30
# 200/200 [==============================] - 1s 5ms/step - loss: 0.1237 - mse: 0.1237
# Epoch 11/30
# 200/200 [==============================] - 1s 5ms/step - loss: 0.1179 - mse: 0.1179
# Epoch 12/30
# 200/200 [==============================] - 1s 6ms/step - loss: 0.1133 - mse: 0.1133
# Epoch 13/30
# 200/200 [==============================] - 2s 9ms/step - loss: 0.1090 - mse: 0.1090
# Epoch 14/30
# 200/200 [==============================] - 3s 15ms/step - loss: 0.1077 - mse: 0.1077
# Epoch 15/30
# 200/200 [==============================] - 1s 7ms/step - loss: 0.1075 - mse: 0.1075
# Epoch 16/30
# 200/200 [==============================] - 1s 6ms/step - loss: 0.1052 - mse: 0.1052
# Epoch 17/30
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1027 - mse: 0.1027
# Epoch 18/30
# 200/200 [==============================] - 1s 6ms/step - loss: 0.1048 - mse: 0.1048
# Epoch 19/30
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1018 - mse: 0.1018
# Epoch 20/30
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0997 - mse: 0.0997
# Epoch 21/30
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0986 - mse: 0.0986
# Epoch 22/30
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1008 - mse: 0.1008
# Epoch 23/30
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0971 - mse: 0.0971
# Epoch 24/30
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1007 - mse: 0.1007
# Epoch 25/30
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0985 - mse: 0.0985
# Epoch 26/30
# 200/200 [==============================] - 1s 6ms/step - loss: 0.1001 - mse: 0.1001
# Epoch 27/30
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0973 - mse: 0.0973
# Epoch 28/30
# 200/200 [==============================] - 1s 6ms/step - loss: 0.0979 - mse: 0.0979
# Epoch 29/30
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0979 - mse: 0.0979
# Epoch 30/30
# 200/200 [==============================] - 2s 9ms/step - loss: 0.0973 - mse: 0.0973

# %%
predict=model.predict(data)
plt.plot(data, predict, 'b', data, y, 'k.') #첫번째 그래프는 파란마커로, 두번째 그래프는 검정색으로 그리기
plt.show()
# Out:
# 7/7 [==============================] - 0s 15ms/step

# %%
predict
# Out:
# array([[4.02317  ],
#        [4.042633 ],
#        [4.062096 ],
#        [4.081558 ],
#        [4.1010213],
#        [4.1204844],
#        [4.1399474],
#        [4.1594105],
#        [4.178873 ],
#        [4.198336 ],
#        [4.217799 ],
#        [4.2372622],
#        [4.2567253],
#        [4.2761884],
#        [4.295651 ],
#        [4.3151135],
#        [4.3345766],
#        [4.3540397],
#        [4.3735027],
#        [4.3929653],
#        [4.4124284],
#        [4.4318914],
#        [4.4513545],
#        [4.4708176],
#        [4.4902797],
#        [4.5097427],
#        [4.529206 ],
#        [4.548669 ],
#        [4.568132 ],
#        [4.5875945],
#        [4.6070576],
#        [4.6265206],
#        [4.6459837],
#        [4.6654468],
#        [4.6849093],
#        [4.704372 ],
#        [4.723835 ],
#        [4.743298 ],
#        [4.762761 ],
#        [4.782224 ],
#        [4.801687 ],
#        [4.82115  ],
#        [4.840613 ],
#        [4.8600755],
#        [4.8795385],
#        [4.899001 ],
#        [4.918464 ],
#        [4.9379272],
#        [4.9573903],
#        [4.9768534],
#        [4.996316 ],
#        [5.015779 ],
#        [5.035242 ],
#        [5.0547047],
#        [5.0741677],
#        [5.0936303],
#        [5.1130934],
#        [5.1325564],
#        [5.1520195],
#        [5.1714826],
#        [5.1909456],
#        [5.210408 ],
#        [5.229871 ],
#        [5.249334 ],
#        [5.268797 ],
#        [5.28826  ],
#        [5.3077226],
#        [5.3271856],
#        [5.3466487],
#        [5.3661118],
#        [5.385575 ],
#        [5.4050374],
#        [5.4245   ],
#        [5.443963 ],
#        [5.463426 ],
#        [5.482889 ],
#        [5.5023518],
#        [5.521815 ],
#        [5.541278 ],
#        [5.560741 ],
#        [5.580204 ],
#        [5.5996666],
#        [5.619129 ],
#        [5.6385922],
#        [5.6580553],
#        [5.6775184],
#        [5.6969814],
#        [5.716444 ],
#        [5.735907 ],
#        [5.75537  ],
#        [5.7748327],
#        [5.794296 ],
#        [5.8137584],
#        [5.8332214],
#        [5.8526845],
#        [5.8721476],
#        [5.8916106],
#        [5.911073 ],
#        [5.9305363],
#        [5.9499993],
#        [5.969462 ],
#        [5.988925 ],
#        [6.008388 ],
#        [6.0278506],
#        [6.0473137],
#        [6.0667768],
#        [6.08624  ],
#        [6.105703 ],
#        [6.1251655],
#        [6.1446285],
#        [6.164091 ],
#        [6.183554 ],
#        [6.203017 ],
#        [6.22248  ],
#        [6.241943 ],
#        [6.261406 ],
#        [6.280869 ],
#        [6.300332 ],
#        [6.3197947],
#        [6.3392572],
#        [6.3587203],
#        [6.3781834],
#        [6.3976464],
#        [6.4171095],
#        [6.436572 ],
#        [6.456035 ],
#        [6.475498 ],
#        [6.4949613],
#        [6.514424 ],
#        [6.5338864],
#        [6.5533495],
#        [6.5728126],
#        [6.5922756],
#        [6.6117387],
#        [6.6312013],
#        [6.6506643],
#        [6.6701274],
#        [6.6895905],
#        [6.709053 ],
#        [6.7285156],
#        [6.7479787],
#        [6.7674417],
#        [6.786905 ],
#        [6.806368 ],
#        [6.825831 ],
#        [6.8452935],
#        [6.8647566],
#        [6.884219 ],
#        [6.903682 ],
#        [6.9231453],
#        [6.942608 ],
#        [6.962071 ],
#        [6.981534 ],
#        [7.000997 ],
#        [7.02046  ],
#        [7.0399227],
#        [7.059386 ],
#        [7.0788484],
#        [7.0983114],
#        [7.1177745],
#        [7.137237 ],
#        [7.1567   ],
#        [7.176163 ],
#        [7.1956263],
#        [7.2150893],
#        [7.234552 ],
#        [7.2540145],
#        [7.2734776],
#        [7.2929406],
#        [7.3124037],
#        [7.3318667],
#        [7.3513293],
#        [7.3707924],
#        [7.3902555],
#        [7.4097185],
#        [7.4291816],
#        [7.4486437],
#        [7.4681067],
#        [7.48757  ],
#        [7.507033 ],
#        [7.526496 ],
#        [7.5459585],
#        [7.5654216],
#        [7.5848846],
#        [7.6043477],
#        [7.6238103],
#        [7.643273 ],
#        [7.662736 ],
#        [7.682199 ],
#        [7.701662 ],
#        [7.721125 ],
#        [7.740588 ],
#        [7.760051 ],
#        [7.779514 ],
#        [7.798977 ],
#        [7.8184395],
#        [7.8379025],
#        [7.857365 ],
#        [7.876828 ],
#        [7.8962913]], dtype=float32)
